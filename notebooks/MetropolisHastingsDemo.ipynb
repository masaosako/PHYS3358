# %% [markdown]
# ## The simplest (and trivial) Markov Chain Monte Carlo code with the Metropolis-Hastings algorithm.
# Sampling from a target distribution $\pi(x)$ = univariate gaussian with $\mu=1$ and $\sigma=2$.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %% [markdown]
# This is the target distribution $\pi(x)$.  Note that this does **not** need to be normalized (try it)!

# %%
def targetPDF(x):
    return stats.norm.pdf(x, loc=1, scale=2)

# %%
xval = np.linspace(-8,10,1000)
pval = targetPDF(xval)
plt.plot(xval, pval)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
np.random.seed(2384)
K     = 10000          # number of candidate steps
x0    = 50             # first guess (well outside)
xstep = 3.0            # step size (note that there are good and bad choices for this value)
p     = targetPDF(x0)  # target \pi(x0)

# %%
# Write this function!
#def MCMC(targetPDF, K, x0, xstep):
#    return samples

# %%
samples = MCMC(targetPDF, K, x0, xstep)
# Out:
# reject / accept fractions =  [0.4132 0.5868]

# %%
xhist = plt.hist(samples, range=[-8,10], bins=50)

# %%
for i in np.arange(K):
    print(samples[i])
# Out:
# 47.95127864346898
# 47.95127864346898
# 44.926265021697425
# 43.400739770410965
# 41.091195103995595
# 38.042148662604035
# 36.29083147856051
# 32.31043060535695
# 32.31043060535695
# 31.117348180149335
# 29.200756216195572
# 29.200756216195572
# 29.200756216195572
# 29.200756216195572
# 25.48518853868081
# 25.48518853868081
# 25.48518853868081
# 23.73750388855554
# 23.380488387345444
# 23.380488387345444
# 19.739935919600313
# 19.739935919600313
# 19.77575192070427
# 19.77575192070427
# 19.593817178778206
# 18.834796697867983
# 18.834796697867983
# 18.454665591813384
# 18.454665591813384
# 18.454665591813384
# 14.059942097519837
# 14.059942097519837
# 14.059942097519837
# 14.059942097519837
# 10.603310374270412
# 5.49057164810935
# -2.0186269085159427
# -2.0186269085159427
# -2.0186269085159427
# -0.2827276736969273
# -1.361965306520869
# -1.361965306520869
# -1.8541643816531606
# -0.40303356079729613
# 0.8999083574656359
# -1.3879591317876765
# -1.0616967174274876
# ...

# %%
# compute mean and std excluding the first 10% of chains (burn in)
print(np.mean(samples[1000:]), np.std(samples[1000:]))
# Out:
# 0.9465805209846629 2.01759802134266

# %%
steps = np.arange(K)

# %%
plt.plot(steps, samples)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# This cells shows the burn-in region where the chain has not yet converged.

# %%
plt.plot(steps, samples)
plt.xlim([-10,100])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
